# %% [markdown]
# <a href="https://colab.research.google.com/github/maramameen14140-bot/-/blob/main/Copy_of_Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.model_download("davidtroxellucla/pygem-using-googles-gemma-for-a-python-chatbot/keras/pygem-original")

print("Path to model files:", path)
# Out:
#  57%|█████▋    | 5.35G/9.34G [00:47<00:23, 181MB/s]
#  57%|█████▋    | 5.37G/9.34G [00:47<00:23, 179MB/s]
#  58%|█████▊    | 5.39G/9.34G [00:47<00:22, 187MB/s]
#  58%|█████▊    | 5.41G/9.34G [00:47<00:22, 191MB/s]
#  58%|█████▊    | 5.43G/9.34G [00:47<00:21, 195MB/s]
#  58%|█████▊    | 5.45G/9.34G [00:48<00:22, 189MB/s]
#  59%|█████▊    | 5.47G/9.34G [00:48<00:20, 199MB/s]
#  59%|█████▉    | 5.49G/9.34G [00:48<00:20, 205MB/s]
#  59%|█████▉    | 5.51G/9.34G [00:48<00:20, 205MB/s]
#  59%|█████▉    | 5.53G/9.34G [00:48<00:20, 197MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4054003593.py in <cell line: 0>()
#       2
#       3 # Download latest version
# ----> 4 path = kagglehub.model_download("davidtroxellucla/pygem-using-googles-gemma-for-a-python-chatbot/keras/pygem-original")
#       5
#       6 print("Path to model files:", path)
#
# ...
